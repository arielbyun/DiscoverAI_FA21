# %% [markdown]
# Last time, we looked at an example reinforcement problem that balanced an object in space following  [this tutorial](https://youtu.be/cO5g5qLrLSo).
#
# In this lab, you will choose a reinforcement learning problem to explore. Here are some suggestions for problems that you can investigate.
#
# 1. Autonomous driving: Building a racing car with reinforcement learning. [Tutorial](https://youtu.be/Mut_u40Sqz4?t=6020), [code on github](https://github.com/nicknochnack/ReinforcementLearningCourse/blob/main/Project%202%20-%20Self%20Driving.ipynb).
# 2. Custom environments: Shower environment to get the temperature right every time. [Tutorial](https://youtu.be/Mut_u40Sqz4?t=6020), [code on github](https://github.com/nicknochnack/ReinforcementLearningCourse/blob/main/Project%203%20-%20Custom%20Environment.ipynb).
# 3. Some other options to check out later if interested:
#     1. Solving the Lunar Landing Problem using Stable Baselines algorithm: [tutorial](https://youtu.be/nRHjymV2PX8), [code on github](https://github.com/nicknochnack/StableBaselinesRL). ACER is only available in a previous version of stable_baselines that is compatible with tensorflow 1.5, which is not available on edStem.
#     2. Datasets for Deep Data-Driven Reinforcement Learning (D4RL): [environments description](https://sites.google.com/view/d4rl/home), [code on github](https://github.com/rail-berkeley/d4rl).
#
# **Note:** This is a rough guide with the general mains steps in a reinforcement learning program. Please add more sections as your implementation requires, with comments describing each section.

# %% [markdown]
# # Problem description
# Enter in the text cell below the problem that you chose to solve with reinforcement learning.

# %% [markdown]
# The problem I decided to solve with reinforment learning was the autonomous drivinf problem since my project group want to focus on the topic of autonomous driving.

# %% [markdown]
# # **Build an RL environment**

# %% [markdown]
# **1. Install packages**
#
# Note: Please inform the TA of any additional packages that you need to install for the problem that you selected.

# %%
import os
if not os.getenv("ED_COURSE_ID"):
    # !pip install tensorflow stable_baselines3 torch collections gym box2d-py --user
# in order to leverage the racing car environment, we do need to install swig
# Install SWIG https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering
# !pip install gym[box2d] pyglet==1.3.2
#racing car environment is built on top of box2d
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gym[box2d] in /usr/lib/python3.9/site-packages (0.21.0)
# Collecting pyglet==1.3.2
#   Using cached pyglet-1.3.2-py2.py3-none-any.whl (1.0 MB)
# Requirement already satisfied: future in /usr/lib/python3.9/site-packages (from pyglet==1.3.2) (0.18.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/lib/python3.9/site-packages (from gym[box2d]) (1.21.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/lib/python3.9/site-packages (from gym[box2d]) (2.0.0)
# Collecting box2d-py==2.3.5
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
# Collecting gym[box2d]
#   Using cached gym-0.21.0.tar.gz (1.5 MB)
#   Using cached gym-0.20.0.tar.gz (1.6 MB)
#   Using cached gym-0.19.0.tar.gz (1.6 MB)
# Collecting cloudpickle<1.7.0,>=1.2.0
#   Using cached cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting box2d-py~=2.3.5
#   Using cached box2d-py-2.3.8.tar.gz (374 kB)
# Collecting gym[box2d]
#   Using cached gym-0.18.3.tar.gz (1.6 MB)
# Requirement already satisfied: scipy in /usr/lib/python3.9/site-packages (from gym[box2d]) (1.7.1)
#   Using cached gym-0.18.0.tar.gz (1.6 MB)
#   Using cached gym-0.17.3.tar.gz (1.6 MB)
#   Using cached gym-0.17.2.tar.gz (1.6 MB)
#   Using cached gym-0.17.1.tar.gz (1.6 MB)
# Requirement already satisfied: six in /usr/lib/python3.9/site-packages (from gym[box2d]) (1.16.0)
#   Using cached gym-0.17.0.tar.gz (1.6 MB)
#   Using cached gym-0.16.0.tar.gz (1.6 MB)
#   Using cached gym-0.15.7.tar.gz (1.6 MB)
#   Using cached gym-0.15.6.tar.gz (1.6 MB)
#   Using cached gym-0.15.4.tar.gz (1.6 MB)
# Collecting cloudpickle~=1.2.0
#   Using cached cloudpickle-1.2.2-py2.py3-none-any.whl (25 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.5.4.58-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.3 MB)
#      |██████��
# [too much output ...]

# %% [markdown]
# **1.b import packages**

# %%
# Add your code here to import all needed packages. 
# Contact the instructor if you get an error.
import gym 
# importing open ai gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %% [markdown]
# **2. Create the environment**

# %%
environment_name = "CarRacing-v0"
env = gym.make(environment_name)
# we're creating our environment

# %% [markdown]
# **3. Test the environment with random policy**

# %%
# Trigger Ed's X display
# !xdpyinfo

# Add your code here to display the environment with random choice
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# this is our testing code!
# Out:
# name of display:    :1.0
# version number:    11.0
# vendor string:    The X.Org Foundation
# vendor release number:    12009000
# X.Org version: 1.20.9
# maximum request size:  16777212 bytes
# motion buffer size:  256
# bitmap unit, bit order, padding:    32, LSBFirst, 32
# image byte order:    LSBFirst
# number of supported pixmap formats:    6
# supported pixmap formats:
#     depth 1, bits_per_pixel 1, scanline_pad 32
#     depth 4, bits_per_pixel 8, scanline_pad 32
#     depth 8, bits_per_pixel 8, scanline_pad 32
#     depth 16, bits_per_pixel 16, scanline_pad 32
#     depth 24, bits_per_pixel 32, scanline_pad 32
#     depth 32, bits_per_pixel 32, scanline_pad 32
# keycode range:    minimum 8, maximum 255
# focus:  window 0x40020b, revert to PointerRoot
# number of extensions:    23
#     BIG-REQUESTS
#     Composite
#     DAMAGE
#     DOUBLE-BUFFER
#     GLX
#     Generic Event Extension
#     MIT-SCREEN-SAVER
#     MIT-SHM
#     Present
#     RANDR
#     RECORD
#     RENDER
#     SHAPE
#     SYNC
#     VNC-EXTENSION
#     X-Resource
#     XC-MISC
#     XFIXES
#     XINERAMA
#     XInputExtension
#     XKEYBOARD
#     XTEST
#     XVideo
# default screen number:    0
# number of screens:    1
#
# screen #0:
#   dimensions:    1276x767 pixels (336x202 millimeters)
#   resolution:    96x96 dots per inch
#   depths (7):    1, 4, 8, 16, 24, 32, 24
#   root window id:    0x51a
#   depth of root window:    24 planes
#   number of colormaps:    minimum 1, maximum 1
#   default colormap:    0x20
#   default number of colormap cells:    256
#   preallocated pixels:    black 0, white 16777215
#   options:    backing-store WHEN MAPPED, save-unders NO
#   largest cursor:    1276x767
#   current input event mask:    0x72003c
#     ButtonPressMask          ButtonReleaseMask        EnterWindowMask
#     LeaveWindowMask          StructureNotifyMask      SubstructureRedirectMask
#     FocusChangeMask          PropertyChangeMask
#   number of visuals:    390
#   default visual id:  0x21
#   visual:
#     visual id:    0x396
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x397
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x398
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x399
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x39f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3a9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3aa
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ab
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ac
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ad
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ae
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3af
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3b9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ba
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3be
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3bf
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3c9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ca
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ce
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3cf
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3d9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3da
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3db
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3dc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3dd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3de
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3df
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3e9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ea
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3eb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ec
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ed
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ee
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ef
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f0
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f1
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f2
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f3
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f4
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f5
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f6
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f7
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f8
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3f9
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fa
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fb
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fc
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fd
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3fe
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x3ff
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x400
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x401
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x402
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x403
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x404
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x405
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x406
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x407
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x408
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x409
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x40f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x410
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x411
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x412
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x413
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x414
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x415
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x416
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x417
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x418
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x419
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x41f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x420
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x421
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x422
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x423
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x424
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x425
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x426
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x427
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x428
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x429
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x42f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x430
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x431
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x432
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x433
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x434
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x435
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x436
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x437
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x438
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x439
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43a
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43b
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43c
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43d
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43e
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x43f
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x440
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x441
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x442
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x443
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x444
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x445
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x446
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x447
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x448
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x449
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44a
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44b
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44c
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44d
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44e
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x44f
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x450
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x451
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x452
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x453
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
# ...
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4dc
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4dd
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4de
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4df
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e0
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e1
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e2
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e3
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e4
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e5
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e6
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e7
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e8
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4e9
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ea
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4eb
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ec
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ed
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ee
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ef
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f0
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f1
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f2
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f3
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f4
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f5
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f6
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f7
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f8
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4f9
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fa
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fb
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4d
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fc
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fd
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4fe
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x4ff
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x500
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x501
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x502
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x503
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x504
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x505
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x506
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x507
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x508
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x509
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50a
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50b
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50c
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50d
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50e
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x50f
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x510
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x511
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x512
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x513
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x514
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x515
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x516
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x517
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x518
#     class:    TrueColor
#     depth:    32 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x21
#     class:    TrueColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
#   visual:
#     visual id:    0x22
#     class:    DirectColor
#     depth:    24 planes
#     available colormap entries:    256 per subfield
#     red, green, blue masks:    0xff0000, 0xff00, 0xff
#     significant bits in color specification:    8 bits
# Track generation: 1123..1408 -> 285-tiles track
# Episode:1 Score:-29.57746478873287
# Track generation: 1117..1401 -> 284-tiles track
# retry to generate track (normal if there are
# [too much output ...]

# %%
env.close()
# closes the environment

# %%
env.action_space.sample()
# Out:
# array([0.7407547 , 0.9964477 , 0.78228635], dtype=float32)

# %%
env.observation_space.sample()
# Out:
# array([[[194,  10,   5],
#         [110,  97,  95],
#         [162,  14, 175],
#         ...,
#         [ 30,  68, 182],
#         [ 41, 243, 148],
#         [116, 249, 246]],
#
#        [[203, 204, 109],
#         [104,  52,  38],
#         [254,  71,  79],
#         ...,
#         [104, 124,  45],
#         [ 67, 200,  70],
#         [140, 135, 178]],
#
#        [[105, 178, 200],
#         [ 18, 250,  76],
#         [184, 170,  25],
#         ...,
#         [224, 157, 148],
#         [137,  34,  55],
#         [135, 149,  69]],
#
#        ...,
#
#        [[ 33,  65,  39],
#         [131,  41,  60],
#         [ 21, 222, 157],
#         ...,
#         [249,   4,  34],
#         [104, 220, 164],
#         [235, 171,  45]],
#
#        [[ 74,  63, 240],
#         [ 75, 168, 157],
#         [ 71, 211,  12],
#         ...,
#         [141,  84, 173],
#         [ 34,  58,   4],
#         [123, 137,  81]],
#
#        [[244,   3, 134],
#         [ 49,  16, 172],
#         [145,  65, 207],
#         ...,
#         [179,  70,  19],
#         [220, 206,  75],
#         [  7, 124, 118]]], dtype=uint8)

# %% [markdown]
# # **Build and Train the Model**

# %% [markdown]
# **4. Build the training model**

# %%
# env = gym.make(environment_name)
# env = VecFrameStack([lambda: env])
# instantiating and setting up our environment

# %%
# setting up our agent and model
log_path = os.path.join('Training', 'Logs')
# specifying our logging path
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# specificied our agent
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=70000)
# here we're training our model for 70000 steps
# Out:
# Track generation: 1040..1304 -> 264-tiles track
# Logging to Training/Logs/PPO_1
# Track generation: 1282..1607 -> 325-tiles track

# %% [markdown]
# # **Save, Reload and Evaluate the model**

# %% [markdown]
# **5. Save the model**

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model')

# %%
model.save(ppo_path)

# %% [markdown]
# **6. Reload the model**

# %%
# Add your code here to test the system:
# Reload the model
# Evaluate and test
del model

# %%
model = PPO.load(ppo_path, env)

# %% [markdown]
# **7. Display the environment**

# %%
# Trigger Ed's X display
# !xdpyinfo
# Add loop here to display the smart agent!
evaluate_policy(model, env, n_eval_episodes=10, render=True)

# %%
env.close()

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()

# %%
env.close()
